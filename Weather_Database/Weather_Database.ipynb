# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Import the time library and the datetime module from the datetime library 
#import time
#from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=083b633c248158602076499e3d8d7201

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | viedma
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | turan
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | praia da vitoria
# Processing Record 7 of Set 1 | goderich
# Processing Record 8 of Set 1 | yulara
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | cherskiy
# Processing Record 13 of Set 1 | bandarbeyla
# Processing Record 14 of Set 1 | olga
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 17 of Set 1 | zheleznodorozhnyy
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | nizwa
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | severo-kurilsk
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | naze
# Processing Record 26 of Set 1 | khatanga
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | mayumba
# Processing Record 29 of Set 1 | oum hadjer
# Processing Record 30 of Set 1 | luderitz
# Processing Record 31 of Set 1 | mount gambier
# Processing Record 32 of Set 1 | la ronge
# Processing Record 33 of Set 1 | iqaluit
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | trinidad
# Processing Record 37 of Set 1 | guerrero negro
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | chokurdakh
# Processing Record 40 of Set 1 | balabac
# Processing Record 41 of Set 1 | coquimbo
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | ngorongoro
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | mahon
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | basco
# Processing Record 49 of Set 1 | lebu
# Processing Record 50 of Set 1 | baiyin
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | grindavik
# Processing Record 3 of Set 2 | obigarm
# Processing Record 4 of Set 2 | miri
# Processing Record 5 of Set 2 | cumaribo
# City not found. Skipping...
# Processing Record 6 of Set 2 | lompoc
# Processing Record 7 of Set 2 | tautira
# Processing Record 8 of Set 2 | nome
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | bacolod
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | hasaki
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | flinders
# Processing Record 17 of Set 2 | tual
# Processing Record 18 of Set 2 | dubti
# Processing Record 19 of Set 2 | itaituba
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | kandrian
# Processing Record 22 of Set 2 | srednekolymsk
# Processing Record 23 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 2 | bunia
# Processing Record 25 of Set 2 | saint george
# Processing Record 26 of Set 2 | nanortalik
# Processing Record 27 of Set 2 | houma
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | verkhoyansk
# Processing Record 30 of Set 2 | boguchany
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | fairbanks
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | manggar
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | necochea
# Processing Record 39 of Set 2 | kayerkan
# Processing Record 40 of Set 2 | codrington
# Processing Record 41 of Set 2 | juxian
# City not found. Skipping...
# Processing Record 42 of Set 2 | ostrovnoy
# Processing Record 43 of Set 2 | mount vernon
# Processing Record 44 of Set 2 | narsaq
# Processing Record 45 of Set 2 | pudozh
# Processing Record 46 of Set 2 | visnes
# Processing Record 47 of Set 2 | ithaca
# Processing Record 48 of Set 2 | almaznyy
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | longhua
# Processing Record 1 of Set 3 | baykit
# Processing Record 2 of Set 3 | lavrentiya
# Processing Record 3 of Set 3 | kavieng
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | rio grande
# Processing Record 6 of Set 3 | kulhudhuffushi
# Processing Record 7 of Set 3 | hamilton
# Processing Record 8 of Set 3 | honningsvag
# Processing Record 9 of Set 3 | atuona
# Processing Record 10 of Set 3 | mongo
# Processing Record 11 of Set 3 | rikitea
# Processing Record 12 of Set 3 | tarime
# Processing Record 13 of Set 3 | sinnamary
# Processing Record 14 of Set 3 | constitucion
# Processing Record 15 of Set 3 | souillac
# Processing Record 16 of Set 3 | cabo san lucas
# Processing Record 17 of Set 3 | lhuntshi
# City not found. Skipping...
# Processing Record 18 of Set 3 | lasa
# Processing Record 19 of Set 3 | clyde river
# Processing Record 20 of Set 3 | wattegama
# Processing Record 21 of Set 3 | provideniya
# Processing Record 22 of Set 3 | youkounkoun
# Processing Record 23 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 3 | gurgan
# City not found. Skipping...
# Processing Record 25 of Set 3 | port lincoln
# Processing Record 26 of Set 3 | kahului
# Processing Record 27 of Set 3 | kapaa
# Processing Record 28 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 3 | tunceli
# Processing Record 30 of Set 3 | arraial do cabo
# Processing Record 31 of Set 3 | atambua
# Processing Record 32 of Set 3 | carnarvon
# Processing Record 33 of Set 3 | kamaishi
# Processing Record 34 of Set 3 | evensk
# Processing Record 35 of Set 3 | thabazimbi
# Processing Record 36 of Set 3 | fortuna
# Processing Record 37 of Set 3 | moranbah
# Processing Record 38 of Set 3 | hobart
# Processing Record 39 of Set 3 | makakilo city
# Processing Record 40 of Set 3 | geraldton
# Processing Record 41 of Set 3 | linjiang
# Processing Record 42 of Set 3 | te anau
# Processing Record 43 of Set 3 | borba
# Processing Record 44 of Set 3 | san quintin
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | vardo
# Processing Record 47 of Set 3 | komsomolskiy
# Processing Record 48 of Set 3 | antofagasta
# Processing Record 49 of Set 3 | bandar-e lengeh
# Processing Record 50 of Set 3 | pinega
# Processing Record 1 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 4 | olafsvik
# Processing Record 3 of Set 4 | saskylakh
# Processing Record 4 of Set 4 | santa cruz
# Processing Record 5 of Set 4 | tillabery
# City not found. Skipping...
# Processing Record 6 of Set 4 | tukrah
# Processing Record 7 of Set 4 | pisco
# Processing Record 8 of Set 4 | thompson
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | isangel
# Processing Record 11 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 4 | ixtapa
# Processing Record 13 of Set 4 | tiznit
# Processing Record 14 of Set 4 | bathsheba
# Processing Record 15 of Set 4 | nuevo progreso
# Processing Record 16 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 4 | severnyy
# Processing Record 18 of Set 4 | pyatnitskoye
# Processing Record 19 of Set 4 | karratha
# Processing Record 20 of Set 4 | esperance
# Processing Record 21 of Set 4 | bredasdorp
# Processing Record 22 of Set 4 | skjervoy
# Processing Record 23 of Set 4 | aguas formosas
# Processing Record 24 of Set 4 | stornoway
# Processing Record 25 of Set 4 | puerto colombia
# Processing Record 26 of Set 4 | henties bay
# Processing Record 27 of Set 4 | olaine
# Processing Record 28 of Set 4 | tomatlan
# Processing Record 29 of Set 4 | tiksi
# Processing Record 30 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 32 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 4 | honiara
# Processing Record 34 of Set 4 | macia
# Processing Record 35 of Set 4 | north bend
# Processing Record 36 of Set 4 | shimoda
# Processing Record 37 of Set 4 | casablanca
# Processing Record 38 of Set 4 | waingapu
# Processing Record 39 of Set 4 | kodiak
# Processing Record 40 of Set 4 | longyan
# Processing Record 41 of Set 4 | salalah
# Processing Record 42 of Set 4 | kannur
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 4 | krasnoznamensk
# Processing Record 46 of Set 4 | isabela
# Processing Record 47 of Set 4 | shingu
# Processing Record 48 of Set 4 | rudnya
# Processing Record 49 of Set 4 | east london
# Processing Record 50 of Set 4 | tupik
# Processing Record 1 of Set 5 | baracoa
# Processing Record 2 of Set 5 | xudat
# Processing Record 3 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 5 | san cristobal
# Processing Record 5 of Set 5 | taitung
# Processing Record 6 of Set 5 | whitehorse
# Processing Record 7 of Set 5 | charters towers
# Processing Record 8 of Set 5 | kuryk
# Processing Record 9 of Set 5 | kailua
# Processing Record 10 of Set 5 | vanavara
# Processing Record 11 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 5 | christchurch
# Processing Record 13 of Set 5 | huilong
# Processing Record 14 of Set 5 | rabaul
# Processing Record 15 of Set 5 | dvinskoy
# Processing Record 16 of Set 5 | tamandare
# Processing Record 17 of Set 5 | san policarpo
# Processing Record 18 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 5 | san roque
# Processing Record 20 of Set 5 | ribeira grande
# Processing Record 21 of Set 5 | lazurne
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | gladstone
# Processing Record 24 of Set 5 | shieli
# Processing Record 25 of Set 5 | lagoa
# Processing Record 26 of Set 5 | arlit
# Processing Record 27 of Set 5 | nokaneng
# Processing Record 28 of Set 5 | mount isa
# Processing Record 29 of Set 5 | sukhumi
# Processing Record 30 of Set 5 | madimba
# Processing Record 31 of Set 5 | sao filipe
# Processing Record 32 of Set 5 | haverfordwest
# Processing Record 33 of Set 5 | new iberia
# Processing Record 34 of Set 5 | cockburn town
# Processing Record 35 of Set 5 | guane
# Processing Record 36 of Set 5 | pishin
# Processing Record 37 of Set 5 | vao
# Processing Record 38 of Set 5 | altay
# Processing Record 39 of Set 5 | pemangkat
# Processing Record 40 of Set 5 | faanui
# Processing Record 41 of Set 5 | bengkulu
# Processing Record 42 of Set 5 | buala
# Processing Record 43 of Set 5 | chincholi
# Processing Record 44 of Set 5 | hay river
# Processing Record 45 of Set 5 | bom jesus da lapa
# Processing Record 46 of Set 5 | saint-pierre
# Processing Record 47 of Set 5 | albina
# Processing Record 48 of Set 5 | aloleng
# Processing Record 49 of Set 5 | redlands
# Processing Record 50 of Set 5 | fort-shevchenko
# Processing Record 1 of Set 6 | baringo
# Processing Record 2 of Set 6 | kloulklubed
# Processing Record 3 of Set 6 | klos
# Processing Record 4 of Set 6 | raga
# Processing Record 5 of Set 6 | broome
# Processing Record 6 of Set 6 | brae
# Processing Record 7 of Set 6 | aksarka
# Processing Record 8 of Set 6 | araouane
# Processing Record 9 of Set 6 | dudinka
# Processing Record 10 of Set 6 | seoul
# Processing Record 11 of Set 6 | margate
# Processing Record 12 of Set 6 | belyy yar
# Processing Record 13 of Set 6 | marsh harbour
# Processing Record 14 of Set 6 | pangody
# Processing Record 15 of Set 6 | tessalit
# Processing Record 16 of Set 6 | ambulu
# Processing Record 17 of Set 6 | tuktoyaktuk
# Processing Record 18 of Set 6 | labuhan
# Processing Record 19 of Set 6 | yeppoon
# Processing Record 20 of Set 6 | kamenka
# Processing Record 21 of Set 6 | kant
# Processing Record 22 of Set 6 | hami
# Processing Record 23 of Set 6 | trelew
# Processing Record 24 of Set 6 | kupino
# Processing Record 25 of Set 6 | orel-izumrud
# Processing Record 26 of Set 6 | masterton
# Processing Record 27 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 28 of Set 6 | sakakah
# Processing Record 29 of Set 6 | andros town
# Processing Record 30 of Set 6 | maun
# Processing Record 31 of Set 6 | athabasca
# Processing Record 32 of Set 6 | kuusamo
# Processing Record 33 of Set 6 | saint anthony
# Processing Record 34 of Set 6 | laguna
# Processing Record 35 of Set 6 | sovetskiy
# Processing Record 36 of Set 6 | havre
# Processing Record 37 of Set 6 | taltal
# Processing Record 38 of Set 6 | turukhansk
# Processing Record 39 of Set 6 | hobyo
# Processing Record 40 of Set 6 | fort smith
# Processing Record 41 of Set 6 | alofi
# Processing Record 42 of Set 6 | kavaratti
# Processing Record 43 of Set 6 | balkanabat
# Processing Record 44 of Set 6 | yellowknife
# Processing Record 45 of Set 6 | achalpur
# Processing Record 46 of Set 6 | xichang
# Processing Record 47 of Set 6 | longyearbyen
# Processing Record 48 of Set 6 | kapoeta
# Processing Record 49 of Set 6 | havelock
# Processing Record 50 of Set 6 | oktyabrskoye
# Processing Record 1 of Set 7 | havoysund
# Processing Record 2 of Set 7 | adrar
# Processing Record 3 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 7 | sitka
# Processing Record 5 of Set 7 | abu kamal
# Processing Record 6 of Set 7 | tuatapere
# Processing Record 7 of Set 7 | ambilobe
# Processing Record 8 of Set 7 | quatre cocos
# Processing Record 9 of Set 7 | cruz grande
# Processing Record 10 of Set 7 | mastung
# Processing Record 11 of Set 7 | kudahuvadhoo
# Processing Record 12 of Set 7 | omboue
# Processing Record 13 of Set 7 | svencionys
# Processing Record 14 of Set 7 | dingle
# Processing Record 15 of Set 7 | hovd
# Processing Record 16 of Set 7 | nelson bay
# Processing Record 17 of Set 7 | half moon bay
# Processing Record 18 of Set 7 | denpasar
# Processing Record 19 of Set 7 | takoradi
# Processing Record 20 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 7 | klaksvik
# Processing Record 22 of Set 7 | beitbridge
# Processing Record 23 of Set 7 | amalapuram
# Processing Record 24 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 7 | airai
# Processing Record 26 of Set 7 | concordia
# Processing Record 27 of Set 7 | asau
# Processing Record 28 of Set 7 | puro
# Processing Record 29 of Set 7 | castro
# Processing Record 30 of Set 7 | rocha
# Processing Record 31 of Set 7 | husavik
# Processing Record 32 of Set 7 | cabedelo
# Processing Record 33 of Set 7 | ziyamet
# City not found. Skipping...
# Processing Record 34 of Set 7 | aklavik
# Processing Record 35 of Set 7 | luanda
# Processing Record 36 of Set 7 | uthal
# Processing Record 37 of Set 7 | daru
# Processing Record 38 of Set 7 | maykain
# City not found. Skipping...
# Processing Record 39 of Set 7 | vila velha
# Processing Record 40 of Set 7 | shenjiamen
# Processing Record 41 of Set 7 | havre-saint-pierre
# Processing Record 42 of Set 7 | portland
# Processing Record 43 of Set 7 | caravelas
# Processing Record 44 of Set 7 | tigzirt
# Processing Record 45 of Set 7 | alice springs
# Processing Record 46 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 47 of Set 7 | tarko-sale
# Processing Record 48 of Set 7 | nalut
# Processing Record 49 of Set 7 | qaqortoq
# Processing Record 50 of Set 7 | norman wells
# Processing Record 1 of Set 8 | namatanai
# Processing Record 2 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 8 | sechura
# Processing Record 4 of Set 8 | gizo
# Processing Record 5 of Set 8 | nioro
# Processing Record 6 of Set 8 | forest
# Processing Record 7 of Set 8 | ignalina
# Processing Record 8 of Set 8 | buraydah
# Processing Record 9 of Set 8 | betki
# City not found. Skipping...
# Processing Record 10 of Set 8 | big spring
# Processing Record 11 of Set 8 | killybegs
# Processing Record 12 of Set 8 | birao
# Processing Record 13 of Set 8 | hammerfest
# Processing Record 14 of Set 8 | bandarban
# Processing Record 15 of Set 8 | mareeba
# Processing Record 16 of Set 8 | kupang
# Processing Record 17 of Set 8 | mackay
# Processing Record 18 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 8 | chicama
# Processing Record 20 of Set 8 | stjordalshalsen
# Processing Record 21 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 8 | nanakuli
# Processing Record 23 of Set 8 | pitimbu
# Processing Record 24 of Set 8 | avera
# Processing Record 25 of Set 8 | ilhabela
# Processing Record 26 of Set 8 | leonidion
# City not found. Skipping...
# Processing Record 27 of Set 8 | zhigansk
# Processing Record 28 of Set 8 | hualmay
# Processing Record 29 of Set 8 | katsuura
# Processing Record 30 of Set 8 | guliston
# Processing Record 31 of Set 8 | westport
# Processing Record 32 of Set 8 | tommot
# Processing Record 33 of Set 8 | gondar
# Processing Record 34 of Set 8 | leningradskiy
# Processing Record 35 of Set 8 | coahuayana
# Processing Record 36 of Set 8 | college
# Processing Record 37 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 8 | grand-lahou
# Processing Record 39 of Set 8 | waipawa
# Processing Record 40 of Set 8 | manosque
# Processing Record 41 of Set 8 | beringovskiy
# Processing Record 42 of Set 8 | birjand
# Processing Record 43 of Set 8 | hanzhong
# Processing Record 44 of Set 8 | toamasina
# Processing Record 45 of Set 8 | srandakan
# Processing Record 46 of Set 8 | gat
# Processing Record 47 of Set 8 | samarai
# Processing Record 48 of Set 8 | maldonado
# Processing Record 49 of Set 8 | hervey bay
# Processing Record 50 of Set 8 | cayenne
# Processing Record 1 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 2 of Set 9 | ilo
# Processing Record 3 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 4 of Set 9 | pathalgaon
# Processing Record 5 of Set 9 | ignacio zaragoza
# Processing Record 6 of Set 9 | padang
# Processing Record 7 of Set 9 | petropavl
# Processing Record 8 of Set 9 | waitati
# Processing Record 9 of Set 9 | chamba
# Processing Record 10 of Set 9 | coihueco
# Processing Record 11 of Set 9 | kroya
# Processing Record 12 of Set 9 | nago
# Processing Record 13 of Set 9 | sokoni
# Processing Record 14 of Set 9 | mizdah
# Processing Record 15 of Set 9 | northam
# Processing Record 16 of Set 9 | methoni
# Processing Record 17 of Set 9 | saint-pascal
# City not found. Skipping...
# Processing Record 18 of Set 9 | aljezur
# Processing Record 19 of Set 9 | revelstoke
# Processing Record 20 of Set 9 | lodja
# Processing Record 21 of Set 9 | princeton
# Processing Record 22 of Set 9 | el badari
# City not found. Skipping...
# Processing Record 23 of Set 9 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 24 of Set 9 | yatou
# Processing Record 25 of Set 9 | cotonou
# Processing Record 26 of Set 9 | oliveira do bairro
# Processing Record 27 of Set 9 | ankang
# Processing Record 28 of Set 9 | da nang
# Processing Record 29 of Set 9 | pakala
# Processing Record 30 of Set 9 | tura
# Processing Record 31 of Set 9 | inuvik
# Processing Record 32 of Set 9 | itacarambi
# Processing Record 33 of Set 9 | lata
# Processing Record 34 of Set 9 | thinadhoo
# Processing Record 35 of Set 9 | grand gaube
# Processing Record 36 of Set 9 | hope mills
# Processing Record 37 of Set 9 | sayula
# Processing Record 38 of Set 9 | shahr-e babak
# Processing Record 39 of Set 9 | kaduqli
# Processing Record 40 of Set 9 | sabha
# Processing Record 41 of Set 9 | emba
# Processing Record 42 of Set 9 | meulaboh
# Processing Record 43 of Set 9 | santa rosa
# Processing Record 44 of Set 9 | itarema
# Processing Record 45 of Set 9 | chumikan
# Processing Record 46 of Set 9 | oeiras do para
# Processing Record 47 of Set 9 | sept-iles
# Processing Record 48 of Set 9 | koumac
# Processing Record 49 of Set 9 | nemuro
# Processing Record 50 of Set 9 | pravia
# Processing Record 1 of Set 10 | luzhou
# Processing Record 2 of Set 10 | olinda
# Processing Record 3 of Set 10 | ilulissat
# Processing Record 4 of Set 10 | kruisfontein
# Processing Record 5 of Set 10 | garhi khairo
# Processing Record 6 of Set 10 | matara
# Processing Record 7 of Set 10 | jimma
# Processing Record 8 of Set 10 | cagsiay
# Processing Record 9 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 10 of Set 10 | richards bay
# Processing Record 11 of Set 10 | gaoual
# Processing Record 12 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 10 | halifax
# Processing Record 14 of Set 10 | saldanha
# Processing Record 15 of Set 10 | ahipara
# Processing Record 16 of Set 10 | cam ranh
# Processing Record 17 of Set 10 | umea
# Processing Record 18 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 19 of Set 10 | ca mau
# Processing Record 20 of Set 10 | escanaba
# Processing Record 21 of Set 10 | gori
# Processing Record 22 of Set 10 | bontang
# Processing Record 23 of Set 10 | aykhal
# Processing Record 24 of Set 10 | luangwa
# Processing Record 25 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 10 | mecca
# Processing Record 28 of Set 10 | mehamn
# Processing Record 29 of Set 10 | qianguo
# Processing Record 30 of Set 10 | liniere
# City not found. Skipping...
# Processing Record 31 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 32 of Set 10 | santa helena
# Processing Record 33 of Set 10 | bardiyah
# Processing Record 34 of Set 10 | rapid city
# Processing Record 35 of Set 10 | jining
# Processing Record 36 of Set 10 | trud
# Processing Record 37 of Set 10 | boca do acre
# Processing Record 38 of Set 10 | pemba
# Processing Record 39 of Set 10 | muros
# Processing Record 40 of Set 10 | mogadishu
# Processing Record 41 of Set 10 | myrtle beach
# Processing Record 42 of Set 10 | casin
# Processing Record 43 of Set 10 | barcelos
# Processing Record 44 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 10 | porto velho
# Processing Record 46 of Set 10 | ugoofaaru
# Processing Record 47 of Set 10 | pangnirtung
# Processing Record 48 of Set 10 | kisangani
# Processing Record 49 of Set 10 | malanje
# Processing Record 50 of Set 10 | sao joao da barra
# Processing Record 1 of Set 11 | port hedland
# Processing Record 2 of Set 11 | sehithwa
# Processing Record 3 of Set 11 | guichicovi
# City not found. Skipping...
# Processing Record 4 of Set 11 | ngunguru
# Processing Record 5 of Set 11 | morehead
# Processing Record 6 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 11 | dipkarpaz
# City not found. Skipping...
# Processing Record 8 of Set 11 | tongren
# Processing Record 9 of Set 11 | oranjemund
# Processing Record 10 of Set 11 | hofn
# Processing Record 11 of Set 11 | moose factory
# Processing Record 12 of Set 11 | maura
# Processing Record 13 of Set 11 | vilhena
# Processing Record 14 of Set 11 | camarzana
# Processing Record 15 of Set 11 | neuquen
# Processing Record 16 of Set 11 | bonavista
# Processing Record 17 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 11 | nikolskoye
# Processing Record 19 of Set 11 | abbeville
# Processing Record 20 of Set 11 | kedrovyy
# Processing Record 21 of Set 11 | boulsa
# Processing Record 22 of Set 11 | port blair
# Processing Record 23 of Set 11 | grand forks
# Processing Record 24 of Set 11 | khuzdar
# Processing Record 25 of Set 11 | yar-sale
# Processing Record 26 of Set 11 | shihezi
# Processing Record 27 of Set 11 | polson
# Processing Record 28 of Set 11 | chachapoyas
# Processing Record 29 of Set 11 | pioner
# Processing Record 30 of Set 11 | mistelbach
# Processing Record 31 of Set 11 | kharp
# Processing Record 32 of Set 11 | yagodnoye
# Processing Record 33 of Set 11 | baneh
# Processing Record 34 of Set 11 | lahij
# Processing Record 35 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 36 of Set 11 | riyadh
# Processing Record 37 of Set 11 | oyama
# Processing Record 38 of Set 11 | surt
# Processing Record 39 of Set 11 | benguela
# Processing Record 40 of Set 11 | peniche
# Processing Record 41 of Set 11 | bosaso
# Processing Record 42 of Set 11 | aviles
# Processing Record 43 of Set 11 | rakiv lis
# Processing Record 44 of Set 11 | murgab
# Processing Record 45 of Set 11 | doctor juan leon mallorquin
# Processing Record 46 of Set 11 | acarau
# Processing Record 47 of Set 11 | nishihara
# Processing Record 48 of Set 11 | sur
# Processing Record 49 of Set 11 | nevelsk
# Processing Record 50 of Set 11 | tabou
# Processing Record 1 of Set 12 | hendersonville
# Processing Record 2 of Set 12 | anadyr
# Processing Record 3 of Set 12 | cravo norte
# Processing Record 4 of Set 12 | chatham
# Processing Record 5 of Set 12 | chingirlau
# Processing Record 6 of Set 12 | kalmunai
# Processing Record 7 of Set 12 | japura
# Processing Record 8 of Set 12 | goundi
# Processing Record 9 of Set 12 | mikhaylovka
# Processing Record 10 of Set 12 | urcos
# Processing Record 11 of Set 12 | dauriya
# Processing Record 12 of Set 12 | marathon
# Processing Record 13 of Set 12 | gigmoto
# Processing Record 14 of Set 12 | nantucket
# Processing Record 15 of Set 12 | ashoknagar
# Processing Record 16 of Set 12 | bilma
# Processing Record 17 of Set 12 | esmeraldas
# Processing Record 18 of Set 12 | tazovskiy
# Processing Record 19 of Set 12 | marfino
# Processing Record 20 of Set 12 | addis zemen
# City not found. Skipping...
# Processing Record 21 of Set 12 | seryshevo
# Processing Record 22 of Set 12 | saurimo
# Processing Record 23 of Set 12 | skelleftea
# Processing Record 24 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 25 of Set 12 | chapais
# Processing Record 26 of Set 12 | bitkine
# Processing Record 27 of Set 12 | ada
# Processing Record 28 of Set 12 | batagay-alyta
# Processing Record 29 of Set 12 | byron bay
# Processing Record 30 of Set 12 | alekseyevskaya
# Processing Record 31 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 12 | bocas del toro
# Processing Record 33 of Set 12 | namibe
# Processing Record 34 of Set 12 | yashkul
# Processing Record 35 of Set 12 | labytnangi
# Processing Record 36 of Set 12 | ilebo
# Processing Record 37 of Set 12 | lebyazhye
# Processing Record 38 of Set 12 | vernon
# Processing Record 39 of Set 12 | changli
# Processing Record 40 of Set 12 | flin flon
# Processing Record 41 of Set 12 | cumadcad
# Processing Record 42 of Set 12 | mana
# Processing Record 43 of Set 12 | rovaniemi
# Processing Record 44 of Set 12 | saint-francois
# Processing Record 45 of Set 12 | ati
# Processing Record 46 of Set 12 | assiniboia
# Processing Record 47 of Set 12 | ossora
# Processing Record 48 of Set 12 | san andres
# Processing Record 49 of Set 12 | rawson
# Processing Record 50 of Set 12 | paysandu
# Processing Record 1 of Set 13 | bangassou
# Processing Record 2 of Set 13 | cidreira
# Processing Record 3 of Set 13 | san patricio
# Processing Record 4 of Set 13 | srivaikuntam
# Processing Record 5 of Set 13 | agadez
# Processing Record 6 of Set 13 | red bank
# Processing Record 7 of Set 13 | campanario
# Processing Record 8 of Set 13 | salto
# Processing Record 9 of Set 13 | teya
# Processing Record 10 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 13 | puri
# Processing Record 12 of Set 13 | washougal
# Processing Record 13 of Set 13 | muravlenko
# Processing Record 14 of Set 13 | roblin
# Processing Record 15 of Set 13 | store heddinge
# Processing Record 16 of Set 13 | tallahassee
# Processing Record 17 of Set 13 | sidlaghatta
# Processing Record 18 of Set 13 | el tigre
# Processing Record 19 of Set 13 | bonaventure
# Processing Record 20 of Set 13 | mut
# Processing Record 21 of Set 13 | sfantu gheorghe
# Processing Record 22 of Set 13 | thiers
# Processing Record 23 of Set 13 | okhotsk
# Processing Record 24 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 13 | borinskoye
# Processing Record 26 of Set 13 | kangaatsiaq
# Processing Record 27 of Set 13 | nouadhibou
# Processing Record 28 of Set 13 | beloha
# Processing Record 29 of Set 13 | jeremie
# Processing Record 30 of Set 13 | tolaga bay
# Processing Record 31 of Set 13 | owando
# Processing Record 32 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 33 of Set 13 | bonthe
# Processing Record 34 of Set 13 | igrim
# Processing Record 35 of Set 13 | hokitika
# Processing Record 36 of Set 13 | novyye burasy
# Processing Record 37 of Set 13 | foso
# Processing Record 38 of Set 13 | galesong
# Processing Record 39 of Set 13 | arden
# Processing Record 40 of Set 13 | gold coast
# Processing Record 41 of Set 13 | kiama
# Processing Record 42 of Set 13 | hambantota
# Processing Record 43 of Set 13 | balgazyn
# Processing Record 44 of Set 13 | never
# Processing Record 45 of Set 13 | elko
# Processing Record 46 of Set 13 | purpe
# Processing Record 47 of Set 13 | kawalu
# Processing Record 48 of Set 13 | savannakhet
# Processing Record 49 of Set 13 | strezhevoy
# Processing Record 50 of Set 13 | nyimba
# Processing Record 1 of Set 14 | sartell
# Processing Record 2 of Set 14 | bogovarovo
# Processing Record 3 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 4 of Set 14 | beisfjord
# Processing Record 5 of Set 14 | lima
# Processing Record 6 of Set 14 | walvis bay
# Processing Record 7 of Set 14 | coos bay
# Processing Record 8 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 14 | plettenberg bay
# Processing Record 10 of Set 14 | chambersburg
# Processing Record 11 of Set 14 | bara
# Processing Record 12 of Set 14 | san pedro
# Processing Record 13 of Set 14 | suez
# Processing Record 14 of Set 14 | shaowu
# Processing Record 15 of Set 14 | shahrud
# Processing Record 16 of Set 14 | butare
# Processing Record 17 of Set 14 | berlevag
# Processing Record 18 of Set 14 | tutoia
# Processing Record 19 of Set 14 | wuwei
# Processing Record 20 of Set 14 | puerto escondido
# Processing Record 21 of Set 14 | tromso
# Processing Record 22 of Set 14 | zharkent
# Processing Record 23 of Set 14 | solano
# Processing Record 24 of Set 14 | sao joao do paraiso
# Processing Record 25 of Set 14 | atasu
# Processing Record 26 of Set 14 | bayir
# Processing Record 27 of Set 14 | tombouctou
# Processing Record 28 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 14 | belaya gora
# Processing Record 30 of Set 14 | cortez
# Processing Record 31 of Set 14 | acajutla
# Processing Record 32 of Set 14 | oktyabrskiy
# Processing Record 33 of Set 14 | wad rawah
# Processing Record 34 of Set 14 | harwich
# Processing Record 35 of Set 14 | kalas
# Processing Record 36 of Set 14 | cuxhaven
# Processing Record 37 of Set 14 | khani
# Processing Record 38 of Set 14 | stykkisholmur
# Processing Record 39 of Set 14 | saint paul
# Processing Record 40 of Set 14 | champerico
# Processing Record 41 of Set 14 | cusco
# Processing Record 42 of Set 14 | novopavlovka
# Processing Record 43 of Set 14 | barguzin
# Processing Record 44 of Set 14 | kununurra
# Processing Record 45 of Set 14 | san vicente
# Processing Record 46 of Set 14 | ochakiv
# Processing Record 47 of Set 14 | soe
# Processing Record 48 of Set 14 | nizhniy kuranakh
# Processing Record 49 of Set 14 | moulins
# Processing Record 50 of Set 14 | blanquefort
# Processing Record 1 of Set 15 | mao
# Processing Record 2 of Set 15 | ambon
# Processing Record 3 of Set 15 | belmonte
# Processing Record 4 of Set 15 | mabaruma
# Processing Record 5 of Set 15 | taraza
# Processing Record 6 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 15 | bratsk
# Processing Record 8 of Set 15 | kautokeino
# Processing Record 9 of Set 15 | tingi
# Processing Record 10 of Set 15 | wanning
# Processing Record 11 of Set 15 | witrivier
# City not found. Skipping...
# Processing Record 12 of Set 15 | panjab
# Processing Record 13 of Set 15 | dunedin
# Processing Record 14 of Set 15 | angoram
# Processing Record 15 of Set 15 | wenzhou
# Processing Record 16 of Set 15 | matadi
# Processing Record 17 of Set 15 | manono
# Processing Record 18 of Set 15 | turmalina
# Processing Record 19 of Set 15 | pelym
# Processing Record 20 of Set 15 | luleburgaz
# Processing Record 21 of Set 15 | kieta
# Processing Record 22 of Set 15 | tateyama
# Processing Record 23 of Set 15 | djambala
# Processing Record 24 of Set 15 | andrychow
# Processing Record 25 of Set 15 | dauphin
# Processing Record 26 of Set 15 | fredericksburg
# Processing Record 27 of Set 15 | togul
# Processing Record 28 of Set 15 | sosnovka
# Processing Record 29 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 30 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 31 of Set 15 | palasa
# Processing Record 32 of Set 15 | okha
# Processing Record 33 of Set 15 | visby
# Processing Record 34 of Set 15 | fare
# Processing Record 35 of Set 15 | guarapari
# Processing Record 36 of Set 15 | sulangan
# Processing Record 37 of Set 15 | keetmanshoop
# Processing Record 38 of Set 15 | bima
# Processing Record 39 of Set 15 | marsa matruh
# Processing Record 40 of Set 15 | kanniyakumari
# Processing Record 41 of Set 15 | kamuli
# Processing Record 42 of Set 15 | nikel
# Processing Record 43 of Set 15 | mahenge
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Busselton -33.6500  115.3333     54.32        79          76
# 1            Viedma -40.8135  -62.9967     68.05        36         100
# 2      Puerto Ayora  -0.7393  -90.3518     81.55        88          94
# 3             Turan  16.0678  108.2208     75.18        88          20
# 4            Torbay  47.6666  -52.7314     49.28        88         100
# 5  Praia Da Vitoria  38.7333  -27.0667     61.05        59          40
# 6          Goderich  43.7501  -81.7165     37.90        75          87
# 7            Yulara -25.2406  130.9889     60.64        29           0
# 8    Port Elizabeth -33.9180   25.5701     67.10        95          40
# 9         Mahebourg -20.4081   57.7000     77.29        83          75
#
#    Wind Speed Country Current Description
# 0        5.48      AU          light rain
# 1        4.81      AR     overcast clouds
# 2        7.00      EC     overcast clouds
# 3        1.14      VN          few clouds
# 4        2.30      CA     overcast clouds
# 5       29.33      PT    scattered clouds
# 6       10.36      CA     overcast clouds
# 7        1.14      AU           clear sky
# 8        9.22      ZA    scattered clouds
# 9       10.36      MU       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton      AU -33.6500  115.3333     54.32        79          76
# 1           Viedma      AR -40.8135  -62.9967     68.05        36         100
# 2     Puerto Ayora      EC  -0.7393  -90.3518     81.55        88          94
# 3            Turan      VN  16.0678  108.2208     75.18        88          20
# 4           Torbay      CA  47.6666  -52.7314     49.28        88         100
# ..             ...     ...      ...       ...       ...       ...         ...
# 673   Marsa Matruh      EG  31.3525   27.2453     62.80        82          20
# 674  Kanniyakumari      IN   8.0833   77.5667     82.49        77         100
# 675         Kamuli      UG   0.9472   33.1197     71.44        69          90
# 676          Nikel      RU  69.4128   30.2220     35.78        97         100
# 677        Mahenge      TZ  -8.6833   36.7167     63.75        91          67
#
#      Wind Speed Current Description
# 0          5.48          light rain
# 1          4.81     overcast clouds
# 2          7.00     overcast clouds
# 3          1.14          few clouds
# 4          2.30     overcast clouds
# ..          ...                 ...
# 673        5.75          few clouds
# 674        9.55     overcast clouds
# 675        2.75     overcast clouds
# 676       21.88     overcast clouds
# 677        3.36       broken clouds
#
# [678 rows x 9 columns]

# %%
city_data_df.count()
# Out:
# City                   678
# Country                678
# Lat                    678
# Lng                    678
# Max Temp               678
# Humidity               678
# Cloudiness             678
# Wind Speed             678
# Current Description    678
# dtype: int64

# %%
# Create the output file (CSV).
output_data_file = "weather_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
